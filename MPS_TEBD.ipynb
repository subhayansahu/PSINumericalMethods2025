# %% [markdown]
# ## Introducion to Tensor Networks and Matrix Product states
# ### PSI Numerical Methods course, Jan 2025
#
# Adapted from the PSI Start minicourse developed by Subhayan Sahu and Yijian Zou

# %%
### If you have not installed the TensorOperations package, uncomment and run the following line
using Pkg; Pkg.add("TensorOperations")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.10/Project.toml`
#   No Changes to `~/.julia/environments/v1.10/Manifest.toml`

# %%
using LinearAlgebra, TensorOperations

# %% [markdown]
# ## MPS basics

# %%
struct myMPS{T<:Number}
    """
    This creates a parameterized type myMPS where:

    - T must be a subtype of Number (like Float64, Complex, etc.)
    - TensorList is a 1D array containing 3D arrays of type T
    - Each 3D tensor represents (left bond, system spin, right bond) indices
    """
    TensorList::Array{Array{T,3},1} #List of myMPS tensors
    #Tensor indices - left bond, system spin, right bond
end

""" The following helper functions extends some base functions to act on our struct type """
Base.length(M::myMPS) = length(M.TensorList)  #number of sites
phys_dim(M::myMPS) = size(M.TensorList[1],2)  #physical dimension
max_bond_dim(M::myMPS) = findmax([size(ten,1) for ten in M.TensorList])[1] #bond dimension
Base.copy(M::myMPS) = myMPS(copy(M.TensorList)) #copy an MPS

# %%
# Create a simple MPS with 2 sites
tensor1 = zeros(Float64, 2,2,2)  # 2×2×2 tensor
tensor2 = zeros(Float64, 2,2,2)  # 2×2×2 tensor
mps = myMPS([tensor1, tensor2])

println(length(mps))        # 2 (sites)
println(phys_dim(mps))      # 2 (physical dimension)
println(max_bond_dim(mps))  # 2 (maximum bond dimension)
# Out:
# 2
# 2
# 2

# %% [markdown]
# ## MPS to dense and dense to MPS

# %%
function randMPS(T::Type,N,d,D)
    ## generate a random MPS with size N, physial dimenson d and bond dimension D
    ## The MPS is in left canonial form
    Ts = Array{T,3}[]
    dL = 1;
    dR = 1;
    for n in 1:N
        dL = dR  ## left bond dimension
        dR = min(D,dL*d,d^n,d^(N-n)) ## right bond dimension
        X = randn(dL*d,dR)
        A = reshape(X,(dL,d,dR))
        push!(Ts,A)
    end
    M = myMPS(Ts)
end
# Out:
# randMPS (generic function with 1 method)

# %%
# Create a random MPS with N sites

N = 8;
d = 2;
D = 10;
mps = randMPS(Float64,N,d,D);

println(length(mps))        # (sites)
println(phys_dim(mps))      # (physical dimension)
println(max_bond_dim(mps))  # (maximum bond dimension)
# Out:
# 8
# 2
# 10

# %%
function MPS_to_dense(M::myMPS{T}) where T
    ## Only run this for small systems!!
    d = phys_dim(M)
    L = length(M)
    tmp = M.TensorList[1]
    for i in 2:L
        A = M.TensorList[i]
        dR = size(A,3)
        @tensor tmp2[l,s1,s2,r] := tmp[l,s1,r1]*A[r1,s2,r]
        tmp = reshape(tmp2,(1,d^i,dR))
    end
    psi = reshape(tmp,d^L)
end
# Out:
# MPS_to_dense (generic function with 1 method)

# %%
function dense_to_MPS(psi::Vector{T},d) where T
    L = convert(Int,round(log(length(psi))/log(d)))
    psi = reshape(psi,(d,d^(L-1)))
    U,S,V = svd(psi)
    A1 = reshape(U,(1,d,d))
    Ts = Array{T,3}[]
    push!(Ts,A1)
    for i in 2:L
        SVt = diagm(S)*V'
        dL = length(S)
        SVt = reshape(SVt,(dL*d,d^(L-i)))
        U,S,V = svd(SVt)
        dR = size(U,2)
        A = reshape(U,(dL,d,dR))
        push!(Ts,A)
    end
    M = myMPS(Ts)
    return M
end
# Out:
# dense_to_MPS (generic function with 1 method)

# %% [markdown]
# ### Exercise: convert MPS to dense and check entropy bound

# %%
N = 8;
d = 2;
D = 10;
M = randMPS(Float64,N,d,D);
psi = MPS_to_dense(M);
for i in 1:N-1
    psi = reshape(psi,(d^i,d^(N-i)))
    S = svdvals(psi)
    S = S./sqrt(sum(S.^2))
    EE = -sum((S.^2).*log.(S.^2))
    println("Across bond $i, EE=$EE")
end
Smax = log(D)
println("Entropy upper bond: $Smax")
# Out:
# Across bond 1, EE=0.006461397440551949
# Across bond 2, EE=0.20902228875609968
# Across bond 3, EE=0.6336766969570384
# Across bond 4, EE=0.9332366842000315
# Across bond 5, EE=0.712921416771392
# Across bond 6, EE=0.4225472991446794
# Across bond 7, EE=0.014424588857828075
# Entropy upper bond: 2.302585092994046

# %% [markdown]
# ### Exercise: dense->MPS->dense

# %%
psi = randn(2^8);
psi = psi/norm(psi);
M = dense_to_MPS(psi,2);
psi2 = MPS_to_dense(M);
dot(psi,psi2)/sqrt(dot(psi2,psi2)) ## overlap
# Out:
# 1.0000000000000009

# %% [markdown]
# ### Exercise: gauge transformation

# %%
M = randMPS(Float64,N,d,D)
M2 = copy(M)
for bond in 1:N-1
    Db = size(M.TensorList[bond],3)
    X = I+randn(Db,Db)
    Xinv = inv(X)
    M2.TensorList[bond] = ncon([M2.TensorList[bond],X],[[-1,-2,1],[1,-3]])
    M2.TensorList[bond+1] = ncon([M2.TensorList[bond+1],Xinv],[[1,-2,-3],[-1,1]])
end
psi1 = MPS_to_dense(M)
psi2 = MPS_to_dense(M2)
dot(psi1,psi2)/(sqrt(dot(psi1,psi1)*dot(psi2,psi2)))
# Out:
# 1.0000000000000007

# %% [markdown]
# ## Canonical form

# %%
function truncate(S::Vector{<:Real}, max_bd::Int, max_err::Float64)
    ## Given an array S (descending), determine the truncation 
    ## based on which of max bond dimesion or max err is reached
    err = 0.0
    set_bd = max_bd
    for i in length(S):-1:1
        err = err + S[i]^2
        if(err>max_err)
            if(i<max_bd)
                set_bd = i
            end
            break
        end
    end
    return set_bd
end
# Out:
# truncate (generic function with 1 method)

# %%
function canonicalize_left_one_site(M::myMPS, site::Int;truncation = false, max_bd = 1024, max_err = 1E-10)
    ## A1 := M[site], A2 := M[site+1]
    ## A1 = USV' => A1=U, A2 = SVt (update)
    ## Truncate S if truncation = true
    ## return S and the updated myMPS M
    A1 = M.TensorList[site]
    DL,d,DR = size(A1)
    A1_mat = reshape(A1, (DL*d,DR))
    U = nothing; S=nothing; V=nothing;
    try
        U,S,V = svd(A1_mat,alg=LinearAlgebra.DivideAndConquer())
    catch
        U,S,V = svd(A1_mat,alg=LinearAlgebra.QRIteration())
    end
    if(norm(S)<eps(Float64))
         throw("zero norm")
    end
    S = S./norm(S)
    if(truncation == true)
        set_bd = truncate(S,max_bd,max_err)
        trunc_err = norm(S[set_bd+1:end])^2
        if(trunc_err>1E-6)
            println("truncation error:",trunc_err)
        end
        S = S[1:set_bd]
        U = U[:,1:set_bd]
        V = V[:,1:set_bd]
    end
    M.TensorList[site] = reshape(U, (DL,d,length(S)))
    if(site<length(M))
        SVt = diagm(0=>S)*V'
        M.TensorList[site+1] = ncon([SVt, M.TensorList[site+1]],[[-1,1],[1,-2,-3]])
    end
    return S, M
end

function canonicalize_right_one_site(M::myMPS, site::Int;truncation = false, max_bd = 1024, max_err = 1E-10)
    ## A1 := M[site], A2 :=M[site-1]
    ## A1 = USV' => A1=V', A2 = US
    ## Truncate S if truncation = true
    A1 = M.TensorList[site]
    DL,d,DR = size(A1)
    A1_mat = reshape(A1, (DL,DR*d))
    U = nothing; S=nothing; V=nothing;
    try
        U,S,V = svd(A1_mat,alg=LinearAlgebra.DivideAndConquer())
    catch
        U,S,V = svd(A1_mat,alg=LinearAlgebra.QRIteration())
    end
    if(norm(S)<eps(Float64))
         throw("zero norm")
    end
    S = S./norm(S)
    if(truncation == true)
        set_bd = truncate(S,max_bd,max_err)
        trunc_err = norm(S[set_bd+1:end])^2
        if(trunc_err>1E-6)
            println("truncation error:",trunc_err)
        end
        S = S[1:set_bd]
        U = U[:,1:set_bd]
        V = V[:,1:set_bd]
    end
    M.TensorList[site] = reshape(V', (length(S),d,DR))
    if(site>1)
        US = U*diagm(0=>S)
        M.TensorList[site-1] = ncon([US, M.TensorList[site-1]],[[1,-3],[-1,-2,1]])
    end
    return S, M
end

function canonicalize_left(M::myMPS;truncation = false, max_bd = 1024, max_err = 1E-10)
    ## Return a left canonical form of the purification (normalized automatically)
    N = length(M)
    for i in 1:N
        ~, M = canonicalize_left_one_site(M, i, truncation=truncation,max_bd=max_bd,max_err=max_err)
    end
    return M
end

function canonicalize_right(M::myMPS;truncation = false, max_bd = 1024, max_err = 1E-10)
    ## Return a right canonical form of the purification (normalized automatically)
    N = length(M)
    for i in N:-1:1
        ~, M = canonicalize_right_one_site(M, i, truncation=truncation,max_bd=max_bd,max_err=max_err)
    end
    return M
end
# Out:
# canonicalize_right (generic function with 1 method)

# %%
M = randMPS(Float64,N,d,D);
M = canonicalize_left(M);
M1 = copy(M);
## You can check here that every tensor satisfies LCC
M = canonicalize_right(M);
M2 = copy(M);
## You can check here that every tensor satisfies RCC
psi1 = MPS_to_dense(M1);
psi2 = MPS_to_dense(M2);
abs(dot(psi1,psi2)) # LCC and RCC represents the same state!
# Out:
# 1.0000000000000004

# %% [markdown]
# ## TEBD

# %%
function product_state_init(T::Type, d::Int, N::Int) 
    ## Initialize a product state |0101010101...>
    ## T - data type
    ## d - local dimension
    ## N - number of sites
    Ten = zeros(T,1,d,1)
    Ten[1,1,1] = 1.0
    myMPSTensors = Array{T,3}[]
    for i in 1:N
        push!(myMPSTensors, Ten)
    end
    return myMPS(myMPSTensors)
end
# Out:
# product_state_init (generic function with 1 method)

# %%
function evolution_two_site(M::myMPS, U::Matrix, site::Int, dir = "l"; truncation = false, max_bd = 1024, max_err=1E-10)
    ## Evolve the pure state by U 
    ## Assuming U is two-site
    ## further assuming the two sites are the center of canonical form if truncation = true (important!)
    ## site is the first site # of the unitary (1 to N-1)
    ## the [site] of the two sites is put into left canonical form (if dir = "l")
    ## the [site+1] of the two sites is put into right canonical form (if dir = "r")
    ## return S and M (automatically normalize the state)
    myMPSTensors = M.TensorList
    @assert site<length(M)
    A1 = myMPSTensors[site]
    A2 = myMPSTensors[site+1]
    d1 = size(A1,2)
    d2 = size(A2,2)
    DL = size(A1,1)
    DR = size(A2,3)
    U = reshape(U,(d1,d2,d1,d2)) # site 1 ket, site 2 ket, site 1 bra, site 2 bra
    A_evol = ncon([A1,A2,U],[[-1,1,2],[2,3,-4],[1,3,-2,-3]])
    A_evol_mat = reshape(A_evol,(DL*d1,DR*d2))
    U2 = nothing; S2=nothing; V2=nothing;
    try
        U2,S2,V2 = svd(A_evol_mat,alg=LinearAlgebra.DivideAndConquer())
    catch
        U2,S2,V2 = svd(A_evol_mat,alg=LinearAlgebra.QRIteration())
    end
    S2 = S2./norm(S2)
    if(truncation == true)
        set_bd = truncate(S2, max_bd, max_err)
        trunc_err = norm(S2[set_bd+1:end])^2
        if(trunc_err>1E-6)
            println("truncation error:",trunc_err)
        end
        S2 = S2[1:set_bd]
        U2 = U2[:,1:set_bd]
        V2 = V2[:,1:set_bd]
    end
    if(dir == "l")
        AL = reshape(U2, (DL,d1,length(S2)))
        AR = reshape(diagm(0=>S2)*V2',(length(S2),d2,DR))
    else
        AL = reshape(U2*diagm(0=>S2), (DL,d1,length(S2)))
        AR = reshape(V2',(length(S2),d2,DR))
    end
    M.TensorList[site] = AL
    M.TensorList[site+1] = AR    
    return S2, M
end
# Out:
# evolution_two_site (generic function with 2 methods)

# %%
function TEBD_layer(M::myMPS, U::Matrix, eo = "o";truncation = false, max_bd = 1024, max_err = 1E-10)
    ## Apply TEBD layer at each even/odd sites
    ## Note - right canonical form assumed in beginning, and left canonical form in the end
    N = length(M)
    d = phys_dim(M)
    if(eo == "o")
        site0 = 1
    else
        S, M = canonicalize_left_one_site(M,1,truncation = truncation, max_bd = max_bd, max_err = max_err)
        site0 = 2
    end
    for site in site0:2:N-1
        S, M = evolution_two_site(M, U, site, "l", truncation = truncation, max_bd = max_bd, max_err = max_err)
        S, M = canonicalize_left_one_site(M,site+1,truncation = truncation, max_bd = max_bd, max_err = max_err)
    end
    return M
end
# Out:
# TEBD_layer (generic function with 2 methods)

# %%
function TEBD_Ising(M0::myMPS,g::Float64,dt::Float64, chimax::Int = 128,err::Float64 = 1E-10, etol = 1E-10, Tmax = 100.0)
    ## Time evolution exp(-TH)|M0> until T=Tmax or energy converges to precision etol
    ## H = - XX - gZ (boundary field cut half)
    ## using second order trotter with time step dt
    ## truncation according to error <= err or bond dimesion reaches chimax
    sigmaX = [[0.0 1.0];[1.0 0.0]]
    sigmaZ = [[1.0 0.0];[0.0 -1.0]]
    Id = [[1.0 0.0];[0.0 1.0]]
    @tensor h12[a,b,c,d] := -sigmaX[a,c]*sigmaX[b,d]-g*sigmaZ[a,c]*Id[b,d]/2-g*Id[a,c]*sigmaZ[b,d]/2
    h12_mat = reshape(h12,(4,4))
    U_half = exp(-dt*h12_mat/2) ##matrix exponential
    U = U_half*U_half 
    
    maxstep = convert(Int,round(Tmax/dt))
    L = length(M0)
    ## compute initial energy
    M = canonicalize_left(M0)
    Ein = 0.0;
    for i in L:-1:2
        AR = M.TensorList[i]
        AL = M.TensorList[i-1]
        Ei = ncon([h12,AL,conj(AL),AR,conj(AR)],[[2,5,3,7],[1,2,4],[1,3,6],[4,5,8],[6,7,8]])
        Ein = Ein+real(Ei[1])
        ~,M = canonicalize_right_one_site(M,i)
    end
    println("Starting TEBD for Ising model, g=$g, L=$L, chimax=$chimax, dt=$dt")
    for step in 1:maxstep
        println("Step $step")
        M = TEBD_layer(M,U_half,"o",truncation = true, max_bd = chimax, max_err = err)
        M = canonicalize_right(M)
        M = TEBD_layer(M,U,"e",truncation = true, max_bd = chimax, max_err = err)
        M = canonicalize_right(M)
        M = TEBD_layer(M,U_half,"o",truncation = true, max_bd = chimax, max_err = err)
        Eout = 0.0;
        for i in L:-1:2
            AR = M.TensorList[i]
            AL = M.TensorList[i-1]
            Ei = ncon([h12,AL,conj(AL),AR,conj(AR)],[[2,5,3,7],[1,2,4],[1,3,6],[4,5,8],[6,7,8]])
            Eout = Eout+real(Ei[1])
            ~,M = canonicalize_right_one_site(M,i)
        end
        bd = max_bond_dim(M)
        println("Maximal bond dimension: $bd")
        if(Ein-Eout<etol)
            println("STOP due to energy convergence. Final energy:$Eout")
            break
        else
            dE = Eout-Ein
            println("Energy = $Eout, energy change = $dE")
            Ein = Eout
        end
        if(step == maxstep)
            println("STOP due to time limit. Final energy:$Eout")
        end
    end
    return M
end
# Out:
# TEBD_Ising (generic function with 5 methods)

# %%
L = 24
d = 2
g = 1.2 #Ising field
chimax = 128 #max bond dim
dt = 0.01 #trotter step
err = 1E-7 #max truncation error
etol = 1E-7 #energy convergence tolerance
Tmax = 20.0 #max imaginary time 

M0 = product_state_init(Float64,d,L);
M = TEBD_Ising(M0,g,dt,chimax,err,etol,Tmax);
# Out:
# Starting TEBD for Ising model, g=1.2, L=24, chimax=128, dt=0.01
# Step 1
# Maximal bond dimension: 2
# Energy = -28.039009991534037, energy change = -0.4390099915340464
# Step 2
# Maximal bond dimension: 2
# Energy = -28.438417990973075, energy change = -0.39940799943903826
# Step 3
# Maximal bond dimension: 2
# Energy = -28.801634113643694, energy change = -0.3632161226706181
# Step 4
# Maximal bond dimension: 2
# Energy = -29.131850944231473, energy change = -0.33021683058777995
# Step 5
# Maximal bond dimension: 2
# Energy = -29.43203726211103, energy change = -0.3001863178795574
# Step 6
# Maximal bond dimension: 2
# Energy = -29.704938028091522, energy change = -0.2729007659804914
# Step 7
# Maximal bond dimension: 2
# Energy = -29.953079065652094, energy change = -0.24814103756057193
# Step 8
# Maximal bond dimension: 2
# Energy = -30.17877512876706, energy change = -0.2256960631149667
# Step 9
# Maximal bond dimension: 2
# Energy = -30.384140289718633, energy change = -0.20536516095157253
# Step 10
# Maximal bond dimension: 2
# Energy = -30.571099795950154, energy change = -0.18695950623152058
# Step 11
# Maximal bond dimension: 2
# Energy = -30.741402731729725, energy change = -0.17030293577957067
# Step 12
# Maximal bond dimension: 2
# Energy = -30.8966349779595, energy change = -0.15523224622977594
# Step 13
# Maximal bond dimension: 2
# Energy = -31.038232093568823, energy change = -0.1415971156093221
# Step 14
# Maximal bond dimension: 2
# Energy = -31.16749184730486, energy change = -0.1292597537360365
# Step 15
# Maximal bond dimension: 2
# Energy = -31.28558621256864, energy change = -0.11809436526377937
# Step 16
# Maximal bond dimension: 2
# Energy = -31.393572703494037, energy change = -0.10798649092539847
# Step 17
# Maximal bond dimension: 2
# Energy = -31.492404980810498, energy change = -0.09883227731646116
# Step 18
# Maximal bond dimension: 2
# Energy = -31.58294269396264, energy change = -0.09053771315214121
# Step 19
# Maximal bond dimension: 2
# Energy = -31.66596055390997, energy change = -0.08301785994732924
# Step 20
# Maximal bond dimension: 2
# Energy = -31.742156651076883, energy change = -0.076196097166914
# Step 21
# Maximal bond dimension: 2
# Energy = -31.81216004679182, energy change = -0.07000339571493797
# Step 22
# Maximal bond dimension: 2
# Energy = -31.876537675669837, energy change = -0.06437762887801668
# Step 23
# Maximal bond dimension: 2
# Energy = -31.935800601895853, energy change = -0.05926292622601537
# Step 24
# Maximal bond dimension: 2
# Energy = -31.990409675177435, energy change = -0.05460907328158271
# Step 25
# Maximal bond dimension: 2
# Energy = -32.040780632977025, energy change = -0.05037095779958989
# Step 26
# Maximal bond dimension: 2
# Energy = -32.08728869506486, energy change = -0.0465080620878382
# Step 27
# Maximal bond dimension: 2
# Energy = -32.13027269489483, energy change = -0.04298399982996415
# Step 28
# Maximal bond dimension: 2
# Energy = -32.170038790122035, energy change = -0.03976609522720764
# Step 29
# Maximal bond dimension: 2
# Energy = -32.20686379200515, energy change = -0.036825001883116215
# Step 30
# Maximal bond dimension: 2
# Energy = -32.24099815065218, energy change = -0.03413435864703018
# Step 31
# Maximal bond dimension: 2
# Energy = -32.272668630208116, energy change = -0.031670479555934605
# Step 32
# Maximal bond dimension: 2
# Energy = -32.30208070524501, energy change = -0.02941207503689469
# Step 33
# Maximal bond dimension: 2
# Energy = -32.32942070686265, energy change = -0.027340001617638165
# Step 34
# Maximal bond dimension: 2
# Energy = -32.354857744386436, energy change = -0.0254370375237869
# Step 35
# Maximal bond dimension: 2
# Energy = -32.37854542608501, energy change = -0.023687681698575602
# Step 36
# Maximal bond dimension: 2
# Energy = -32.400623400036864, energy change = -0.02207797395185196
# Step 37
# Maximal bond dimension: 2
# Energy = -32.421218734160355, energy change = -0.020595334123491682
# Step 38
# Maximal bond dimension: 2
# Energy = -32.4404471524823, energy change = -0.01922841832194422
# Step 39
# Maximal bond dimension: 2
# Energy = -32.458414142953515, energy change = -0.017966990471215638
# Step 40
# Maximal bond dimension: 2
# Energy = -32.47521595051539, energy change = -0.016801807561876103
# Step 41
# Maximal bond dimension: 2
# Energy = -32.49094046767258, energy change = -0.0157245171571887
# Step 42
# Maximal bond dimension: 2
# Energy = -32.505668033519434, energy change = -0.014727565846854418
# Step 43
# Maximal bond dimension: 2
# Energy = -32.51947215099376, energy change = -0.013804117474322197
# Step 44
# Maximal bond dimension: 2
# Energy = -32.532420131077366, energy change = -0.012947980083609423
# Step 45
# Maximal bond dimension: 2
# Energy = -32.544573671720016, energy change = -0.012153540642650285
# Step 46
# Maximal bond dimension: 2
# Energy = -32.555989378419, energy change = -0.011415706698983286
# Step 47
# Maximal bond dimension: 2
# Energy = -32.566719232634206, energy change = -0.010729854215206558
# Step 48
# Maximal bond dimension: 2
# Energy = -32.5768110135461, energy change = -0.010091780911892556
# Step 49
# Maximal bond dimension: 2
# Energy = -32.58630867806518, energy change = -0.009497664519081184
# Step 50
# Maximal bond dimension: 2
# Energy = -32.5952527034679, energy change = -0.008944025402719546
# Step 51
# Maximal bond dimension: 2
# Energy = -32.603680396559376, energy change = -0.00842769309147684
# Step 52
# Maximal bond dimension: 2
# Energy = -32.61162617283989, energy change = -0.007945776280514849
# Step 53
# Maximal bond dimension: 2
# Energy = -32.61912180877654, energy change = -0.007495635936649592
# Step 54
# Maximal bond dimension: 2
# Energy = -32.62619666994638, energy change = -0.007074861169840574
# Step 55
# Maximal bond dimension: 2
# Energy = -32.63287791752015, energy change = -0.0066812475737663135
# Step 56
# Maximal bond dimension: 2
# Energy = -32.63919069529028, energy change = -0.006312777770133948
# Step 57
# Maximal bond dimension: 2
# Energy = -32.64515829921216, energy change = -0.005967603921881448
# Step 58
# Maximal bond dimension: 2
# Energy = -32.650802331217015, energy change = -0.005644032004852306
# Step 59
# Maximal bond dimension: 2
# Energy = -32.656142838869066, energy change = -0.005340507652050519
# Step 60
# Maximal bond dimension: 2
# Energy = -32.66119844227351, energy change = -0.005055603404443332
# Step 61
# Maximal bond dimension: 2
# Energy = -32.6659864494934, energy change = -0.004788007219893586
# Step 62
# Maximal bond dimension: 2
# Energy = -32.67052296160271, energy change = -0.004536512109304169
# Step 63
# Maximal bond dimension: 2
# Energy = -32.67482296838489, energy change = -0.0043000067821807875
# Step 64
# Maximal bond dimension: 2
# Energy = -32.67890043558216, energy change = -0.004077467197269868
# Step 65
# Maximal bond dimension: 2
# Energy = -32.682768384507185, energy change = -0.003867948925027065
# Step 66
# Maximal bond dimension: 2
# Energy = -32.686438964745726, energy change = -0.0036705802385412767
# Step 67
# Maximal bond dimension: 2
# Energy = -32.689923520604836, energy change = -0.0034845558591101167
# Step 68
# Maximal bond dimension: 2
# Energy = -32.693232651894334, energy change = -0.0033091312894981684
# Step 69
# Maximal bond dimension: 2
# Energy = -32.69637626957104, energy change = -0.003143617676705901
# Step 70
# Maximal bond dimension: 2
# Energy = -32.6993636467208, energy change = -0.0029873771497577195
# Step 71
# Maximal bond dimension: 2
# Energy = -32.70220346530788, energy change = -0.002839818587084153
# Step 72
# Maximal bond dimension: 2
# Energy = -32.70490384916717, energy change = -0.0027003838592847274
# Step 73
# Maximal bond dimension: 2
# Energy = -32.70747270801773, energy change = -0.0025688588505659027
# Step 74
# Maximal bond dimension: 2
# Energy = -32.709916909185004, energy change = -0.0024442011672718422
# Step 75
# Maximal bond dimension: 3
# Energy = -32.712283975003274, energy change = -0.0023670658182695092
# Step 76
# Maximal bond dimension: 3
# Energy = -32.714500872685484, energy change = -0.002216897682210117
# Step 77
# Maximal bond dimension: 3
# Energy = -32.71665085053734, energy change = -0.002149977851857443
# Step 78
# Maximal bond dimension: 3
# Energy = -32.71869966033525, energy change = -0.0020488097979054487
# Step 79
# Maximal bond dimension: 3
# Energy = -32.720652617656334, energy change = -0.0019529573210874673
# Step 80
# Maximal bond dimension: 3
# Energy = -32.722514715479285, energy change = -0.001862097822950659
# Step 81
# Maximal bond dimension: 3
# Energy = -32.72429064730672, energy change = -0.0017759318274315206
# Step 82
# Maximal bond dimension: 3
# Energy = -32.725984828334695, energy change = -0.0016941810279789138
# Step 83
# Maximal bond dimension: 3
# Energy = -32.727601414858796, energy change = -0.0016165865241006827
# Step 84
# Maximal bond dimension: 3
# Energy = -32.729144322085965, energy change = -0.001542907227168655
# Step 85
# Maximal bond dimension: 3
# Energy = -32.730617240502895, energy change = -0.0014729184169297582
# Step 86
# Maximal bond dimension: 3
# Energy = -32.732023650936014, energy change = -0.0014064104331197314
# Step 87
# Maximal bond dimension: 3
# Energy = -32.733366924285065, energy change = -0.0013432733490503779
# Step 88
# Maximal bond dimension: 3
# Energy = -32.73465033470591, energy change = -0.0012834104208465646
# Step 89
# Maximal bond dimension: 3
# Energy = -32.73587653639069, energy change = -0.0012262016847799373
# Step 90
# Maximal bond dimension: 3
# Energy = -32.73704830052558, energy change = -0.0011717641348880647
# Step 91
# Maximal bond dimension: 3
# Energy = -32.73820865936126, energy change = -0.0011603588356834393
# Step 92
# Maximal bond dimension: 3
# Energy = -32.739421808735855, energy change = -0.0012131493745926036
# Step 93
# Maximal bond dimension: 3
# Energy = -32.74045179584247, energy change = -0.0010299871066123956
# Step 94
# Maximal bond dimension: 3
# Energy = -32.741474948698105, energy change = -0.001023152855637477
# Step 95
# Maximal bond dimension: 3
# Energy = -32.74258520005139, energy change = -0.0011102513532819103
# Step 96
# Maximal bond dimension: 3
# Energy = -32.74364377629693, energy change = -0.0010585762455406211
# Step 97
# Maximal bond dimension: 3
# Energy = -32.74465369179967, energy change = -0.001009915502741876
# Step 98
# Maximal bond dimension: 3
# Energy = -32.74561772328298, energy change = -0.0009640314833134767
# Step 99
# Maximal bond dimension: 3
# Energy = -32.74653843407974, energy change = -0.0009207107967554862
# Step 100
# Maximal bond dimension: 3
# Energy = -32.74741819551316, energy change = -0.0008797614334241644
# Step 101
# Maximal bond dimension: 3
# Energy = -32.74825920577046, energy change = -0.0008410102572966593
# Step 102
# Maximal bond dimension: 3
# Energy = -32.749063506585294, energy change = -0.0008043008148348463
# Step 103
# Maximal bond dimension: 3
# Energy = -32.749832998004315, energy change = -0.0007694914190210511
# Step 104
# Maximal bond dimension: 3
# Energy = -32.75056945147698, energy change = -0.0007364534726619354
# Step 105
# Maximal bond dimension: 3
# Energy = -32.751274521477185, energy change = -0.0007050700002082522
# Step 106
# Maximal bond dimension: 3
# Energy = -32.751949755838176, energy change = -0.0006752343609903733
# Step 107
# Maximal bond dimension: 3
# Energy = -32.75259660495873, energy change = -0.0006468491205566806
# Step 108
# Maximal bond dimension: 3
# Energy = -32.75321643001859, energy change = -0.0006198250598572486
# Step 109
# Maximal bond dimension: 3
# Energy = -32.75381051032302, energy change = -0.0005940803044310883
# Step 110
# Maximal bond dimension: 3
# Energy = -32.75438004988149, energy change = -0.0005695395584695007
# Step 111
# Maximal bond dimension: 3
# Energy = -32.754926183311404, energy change = -0.000546133429914164
# Step 112
# Maximal bond dimension: 3
# Energy = -32.755449981147315, energy change = -0.0005237978359105
# Step 113
# Maximal bond dimension: 3
# Energy = -32.75595245462471, energy change = -0.0005024734773968476
# Step 114
# Maximal bond dimension: 3
# Energy = -32.75643455999958, energy change = -0.0004821053748713666
# Step 115
# Maximal bond dimension: 3
# Energy = -32.75689720245701, energy change = -0.00046264245742833054
# Step 116
# Maximal bond dimension: 3
# Energy = -32.757341239655425, energy change = -0.0004440371984131275
# Step 117
# Maximal bond dimension: 3
# Energy = -32.75776748494717, energy change = -0.00042624529174872805
# Step 118
# Maximal bond dimension: 3
# Energy = -32.758176710311666, energy change = -0.00040922536449272684
# Step 119
# Maximal bond dimension: 3
# Energy = -32.75856964903189, energy change = -0.00039293872022483356
# Step 120
# Maximal bond dimension: 3
# Energy = -32.75894699814245, energy change = -0.0003773491105576454
# Step 121
# Maximal bond dimension: 3
# Energy = -32.75930942067312, energy change = -0.0003624225306708695
# Step 122
# Maximal bond dimension: 3
# Energy = -32.759657547709274, energy change = -0.00034812703615472174
# Step 123
# Maximal bond dimension: 3
# Energy = -32.759991980288056, energy change = -0.00033443257878218446
# Step 124
# Maximal bond dimension: 3
# Energy = -32.76031329114693, energy change = -0.0003213108588724367
# Step 125
# Maximal bond dimension: 3
# Energy = -32.76062202633914, energy change = -0.00030873519221330525
# Step 126
# Maximal bond dimension: 3
# Energy = -32.76091870672917, energy change = -0.00029668039002928026
# Step 127
# Maximal bond dimension: 3
# Energy = -32.76120382937963, energy change = -0.00028512265046032326
# Step 128
# Maximal bond dimension: 3
# Energy = -32.761477868839705, energy change = -0.0002740394600735385
# Step 129
# Maximal bond dimension: 3
# Energy = -32.76174127834435, energy change = -0.0002634095046474272
# Step 130
# Maximal bond dimension: 3
# Energy = -32.761994490932096, energy change = -0.0002532125877436897
# Step 131
# Maximal bond dimension: 3
# Energy = -32.76223792048874, energy change = -0.00024342955664025112
# Step 132
# Maximal bond dimension: 3
# Energy = -32.76247196272344, energy change = -0.0002340422347018034
# Step 133
# Maximal bond dimension: 3
# Energy = -32.76269699608256, energy change = -0.00022503335912205102
# Step 134
# Maximal bond dimension: 3
# Energy = -32.76291338260687, energy change = -0.0002163865243076657
# Step 135
# Maximal bond dimension: 3
# Energy = -32.76312146873624, energy change = -0.00020808612936917825
# Step 136
# Maximal bond dimension: 3
# Energy = -32.76332158606635, energy change = -0.00020011733010960597
# Step 137
# Maximal bond dimension: 3
# Energy = -32.76351405206085, energy change = -0.00019246599450184476
# Step 138
# Maximal bond dimension: 3
# Energy = -32.76369917072251, energy change = -0.00018511866166193158
# Step 139
# Maximal bond dimension: 3
# Energy = -32.76387723322632, energy change = -0.0001780625038065864
# Step 140
# Maximal bond dimension: 3
# Energy = -32.764048518517164, energy change = -0.0001712852908468676
# Step 141
# Maximal bond dimension: 3
# Energy = -32.764213293875, energy change = -0.0001647753578382094
# Step 142
# Maximal bond dimension: 3
# Energy = -32.764371815449174, energy change = -0.00015852157417128865
# Step 143
# Maximal bond dimension: 3
# Energy = -32.764524328764494, energy change = -0.00015251331532084578
# Step 144
# Maximal bond dimension: 3
# Energy = -32.76467106920066, energy change = -0.00014674043616480503
# Step 145
# Maximal bond dimension: 3
# Energy = -32.7648122624469, energy change = -0.00014119324624317642
# Step 146
# Maximal bond dimension: 3
# Energy = -32.76494812493329, energy change = -0.00013586248638830511
# Step 147
# Maximal bond dimension: 3
# Energy = -32.76507886424037, energy change = -0.00013073930708173975
# Step 148
# Maximal bond dimension: 3
# Energy = -32.76520467948815, energy change = -0.0001258152477774388
# Step 149
# Maximal bond dimension: 3
# Energy = -32.765325761706045, energy change = -0.00012108221789475238
# Step 150
# Maximal bond dimension: 3
# Energy = -32.765442294184645, energy change = -0.00011653247860010651
# Step 151
# Maximal bond dimension: 3
# Energy = -32.76555445281042, energy change = -0.00011215862577529379
# Step 152
# Maximal bond dimension: 3
# Energy = -32.765662406384465, energy change = -0.00010795357404447259
# Step 153
# Maximal bond dimension: 3
# Energy = -32.76576631692598, energy change = -0.00010391054151881463
# Step 154
# Maximal bond dimension: 3
# Energy = -32.76586633996158, energy change = -0.00010002303559986103
# Step 155
# Maximal bond dimension: 3
# Energy = -32.76596262480087, energy change = -9.628483928736387e-5
# Step 156
# Maximal bond dimension: 3
# Energy = -32.76605531479945, energy change = -9.26899985813634e-5
# Step 157
# Maximal bond dimension: 3
# Energy = -32.766144547609656, energy change = -8.923281020400964e-5
# Step 158
# Maximal bond dimension: 3
# Energy = -32.76623045541989, energy change = -8.590781023087857e-5
# Step 159
# Maximal bond dimension: 3
# Energy = -32.76631316518309, energy change = -8.270976320545742e-5
# Step 160
# Maximal bond dimension: 3
# Energy = -32.76639279883477, energy change = -7.963365167995562e-5
# Step 161
# Maximal bond dimension: 3
# Energy = -32.76646947350144, energy change = -7.66746666656104e-5
# Step 162
# Maximal bond dimension: 3
# Energy = -32.76654330169956, energy change = -7.382819812562502e-5
# Step 163
# Maximal bond dimension: 3
# Energy = -32.766614391525756, energy change = -7.108982619286053e-5
# Step 164
# Maximal bond dimension: 3
# Energy = -32.76668284683857, energy change = -6.84553128138532e-5
# Step 165
# Maximal bond dimension: 3
# Energy = -32.76674876743237, energy change = -6.592059379784132e-5
# Step 166
# Maximal bond dimension: 3
# Energy = -32.766812249203404, energy change = -6.348177103632224e-5
# Step 167
# Maximal bond dimension: 3
# Energy = -32.76687338430885, energy change = -6.1135105447363e-5
# Step 168
# Maximal bond dimension: 3
# Energy = -32.76693226131886, energy change = -5.887701000517609e-5
# Step 169
# Maximal bond dimension: 3
# Energy = -32.76698896536203, energy change = -5.6704043174704566e-5
# Step 170
# Maximal bond dimension: 3
# Energy = -32.76704357826476, energy change = -5.461290272990027e-5
# Step 171
# Maximal bond dimension: 3
# Energy = -32.767096178684405, energy change = -5.2600419643056284e-5
# Step 172
# Maximal bond dimension: 3
# Energy = -32.767146842236976, energy change = -5.066355257099531e-5
# Step 173
# Maximal bond dimension: 3
# Energy = -32.76719564161927, energy change = -4.879938229152003e-5
# Step 174
# Maximal bond dimension: 3
# Energy = -32.76724264672589, energy change = -4.700510662303259e-5
# Step 175
# Maximal bond dimension: 3
# Energy = -32.7672879247613, energy change = -4.5278035408102824e-5
# Step 176
# Maximal bond dimension: 3
# Energy = -32.76733154034721, energy change = -4.361558590915138e-5
# Step 177
# Maximal bond dimension: 3
# Energy = -32.76737355562536, energy change = -4.2015278154394764e-5
# Step 178
# Maximal bond dimension: 3
# Energy = -32.76741403035617, energy change = -4.0474730809592074e-5
# Step 179
# Maximal bond dimension: 3
# Energy = -32.76745302201307, energy change = -3.899165690057771e-5
# Step 180
# Maximal bond dimension: 3
# Energy = -32.767490585873105, energy change = -3.7563860033174024e-5
# Step 181
# Maximal bond dimension: 3
# Energy = -32.76752677510364, energy change = -3.618923053494427e-5
# Step 182
# Maximal bond dimension: 3
# Energy = -32.76756164084561, energy change = -3.486574196642778e-5
# Step 183
# Maximal bond dimension: 3
# Energy = -32.767595232293175, energy change = -3.359144756842625e-5
# Step 184
# Maximal bond dimension: 3
# Energy = -32.76762759677031, energy change = -3.2364477135615743e-5
# Step 185
# Maximal bond dimension: 3
# Energy = -32.76765877980411, energy change = -3.1183033797788084e-5
# Step 186
# Maximal bond dimension: 3
# Energy = -32.76768882519502, energy change = -3.004539091477909e-5
# Step 187
# Maximal bond dimension: 3
# Energy = -32.767717775084506, energy change = -2.89498894829876e-5
# Step 188
# Maximal bond dimension: 3
# Energy = -32.76774567001959, energy change = -2.7894935087147132e-5
# Step 189
# Maximal bond dimension: 3
# Energy = -32.767772549015106, energy change = -2.6878995512902293e-5
# Step 190
# Maximal bond dimension: 3
# Energy = -32.767798449613146, energy change = -2.5900598039640954e-5
# Step 191
# Maximal bond dimension: 3
# Energy = -32.76782340794036, energy change = -2.495832721649549e-5
# Step 192
# Maximal bond dimension: 3
# Energy = -32.76784745876273, energy change = -2.4050822368337776e-5
# Step 193
# Maximal bond dimension: 3
# Energy = -32.767870635538266, energy change = -2.3176775535205252e-5
# Step 194
# Maximal bond dimension: 3
# Energy = -32.767892970467585, energy change = -2.2334929319356434e-5
# Step 195
# Maximal bond dimension: 3
# Energy = -32.767914494542374, energy change = -2.1524074789169845e-5
# Step 196
# Maximal bond dimension: 3
# Energy = -32.76793523759202, energy change = -2.0743049645943756e-5
# Step 197
# Maximal bond dimension: 3
# Energy = -32.76795522832828, energy change = -1.9990736262798237e-5
# Step 198
# Maximal bond dimension: 3
# Energy = -32.7679744943883, energy change = -1.9266060014899722e-5
# Step 199
# Maximal bond dimension: 3
# Energy = -32.76799306237578, energy change = -1.8567987481787895e-5
# Step 200
# Maximal bond dimension: 3
# Energy = -32.768084299833845, energy change = -9.123745806505212e-5
# Step 201
# Maximal bond dimension: 3
# Energy = -32.76823580768736, energy change = -0.00015150785351636387
# Step 202
# Maximal bond dimension: 3
# Energy = -32.76837434857794, energy change = -0.00013854089058185082
# Step 203
# Maximal bond dimension: 3
# Energy = -32.768501265768144, energy change = -0.00012691719020097025
# Step 204
# Maximal bond dimension: 3
# Energy = -32.76861774671677, energy change = -0.00011648094862692915
# Step 205
# Maximal bond dimension: 3
# Energy = -32.76872484241026, energy change = -0.0001070956934867695
# Step 206
# Maximal bond dimension: 3
# Energy = -32.768823484188275, energy change = -9.864177801688356e-5
# Step 207
# Maximal bond dimension: 3
# Energy = -32.768914498398054, energy change = -9.101420977941643e-5
# Step 208
# Maximal bond dimension: 3
# Energy = -32.76899861916705, energy change = -8.412076899588783e-5
# Step 209
# Maximal bond dimension: 3
# Energy = -32.76907649954349, energy change = -7.788037643763346e-5
# Step 210
# Maximal bond dimension: 3
# Energy = -32.76914872122087, energy change = -7.222167738518692e-5
# Step 211
# Maximal bond dimension: 3
# Energy = -32.76921580303283, energy change = -6.708181195591578e-5
# Step 212
# Maximal bond dimension: 3
# Energy = -32.76927820837955, energy change = -6.240534672485865e-5
# Step 213
# Maximal bond dimension: 3
# Energy = -32.76933635172566, energy change = -5.814334610931837e-5
# Step 214
# Maximal bond dimension: 3
# Energy = -32.769390604290024, energy change = -5.425256436097925e-5
# Step 215
# Maximal bond dimension: 3
# Energy = -32.7694412990322, energy change = -5.069474217833658e-5
# Step 216
# Maximal bond dimension: 3
# Energy = -32.769488735026584, energy change = -4.74359943822833e-5
# Step 217
# Maximal bond dimension: 3
# Energy = -32.76953318130214, energy change = -4.444627555244551e-5
# Step 218
# Maximal bond dimension: 3
# Energy = -32.7695748802166, energy change = -4.169891446537122e-5
# Step 219
# Maximal bond dimension: 3
# Energy = -32.76961405042402, energy change = -3.917020741539545e-5
# Step 220
# Maximal bond dimension: 3
# Energy = -32.769650889486975, energy change = -3.683906295748329e-5
# Step 221
# Maximal bond dimension: 3
# Energy = -32.76968557617847, energy change = -3.468669149242487e-5
# Step 222
# Maximal bond dimension: 3
# Energy = -32.76971827251205, energy change = -3.269633358371493e-5
# Step 223
# Maximal bond dimension: 3
# Energy = -32.76974912553408, energy change = -3.085302202521234e-5
# Step 224
# Maximal bond dimension: 3
# Energy = -32.7697782689075, energy change = -2.9143373424744823e-5
# Step 225
# Maximal bond dimension: 3
# Energy = -32.76980582431316, energy change = -2.7555405658574728e-5
# Step 226
# Maximal bond dimension: 3
# Energy = -32.7698319026903, energy change = -2.6078377139526765e-5
# Step 227
# Maximal bond dimension: 3
# Energy = -32.76985660533637, energy change = -2.470264607268291e-5
# Step 228
# Maximal bond dimension: 3
# Energy = -32.76988002488295, energy change = -2.341954657936185e-5
# Step 229
# Maximal bond dimension: 3
# Energy = -32.76990224616263, energy change = -2.2221279678547035e-5
# Step 230
# Maximal bond dimension: 3
# Energy = -32.76992334697986, energy change = -2.1100817228614233e-5
# Step 231
# Maximal bond dimension: 3
# Energy = -32.769943398797274, energy change = -2.0051817415378537e-5
# Step 232
# Maximal bond dimension: 3
# Energy = -32.76996246734727, energy change = -1.9068549995893136e-5
# Step 233
# Maximal bond dimension: 3
# Energy = -32.76998061317774, energy change = -1.8145830466664847e-5
# Step 234
# Maximal bond dimension: 3
# Energy = -32.769997892139486, energy change = -1.7278961749411792e-5
# Step 235
# Maximal bond dimension: 3
# Energy = -32.77001435631267, energy change = -1.646417318568183e-5
# Step 236
# Maximal bond dimension: 3
# Energy = -32.77003005315142, energy change = -1.5696838751466657e-5
# Step 237
# Maximal bond dimension: 3
# Energy = -32.770045029397, energy change = -1.4976245573450342e-5
# Step 238
# Maximal bond dimension: 3
# Energy = -32.770059323309866, energy change = -1.4293912869334235e-5
# Step 239
# Maximal bond dimension: 3
# Energy = -32.770072972940895, energy change = -1.3649631029011289e-5
# Step 240
# Maximal bond dimension: 3
# Energy = -32.77008601366964, energy change = -1.304072874575013e-5
# Step 241
# Maximal bond dimension: 3
# Energy = -32.770098478432985, energy change = -1.2464763344155472e-5
# Step 242
# Maximal bond dimension: 3
# Energy = -32.77011039793105, energy change = -1.1919498064116851e-5
# Step 243
# Maximal bond dimension: 4
# Energy = -32.77014124788061, energy change = -3.084994956026321e-5
# Step 244
# Maximal bond dimension: 4
# Energy = -32.77017177505611, energy change = -3.052717550389161e-5
# Step 245
# Maximal bond dimension: 4
# Energy = -32.770182376674065, energy change = -1.0601617951522257e-5
# Step 246
# Maximal bond dimension: 4
# Energy = -32.77019253481287, energy change = -1.0158138806559691e-5
# Step 247
# Maximal bond dimension: 4
# Energy = -32.77020227142276, energy change = -9.736609889898773e-6
# Step 248
# Maximal bond dimension: 4
# Energy = -32.77021160710328, energy change = -9.335680516642242e-6
# Step 249
# Maximal bond dimension: 4
# Energy = -32.77022056120626, energy change = -8.95410298085153e-6
# Step 250
# Maximal bond dimension: 4
# Energy = -32.77022915192952, energy change = -8.590723261647781e-6
# Step 251
# Maximal bond dimension: 4
# Energy = -32.7702373964022, energy change = -8.24447268144013e-6
# Step 252
# Maximal bond dimension: 4
# Energy = -32.770245310762625, energy change = -7.914360423910693e-6
# Step 253
# Maximal bond dimension: 4
# Energy = -32.770252910229345, energy change = -7.599466719909742e-6
# Step 254
# Maximal bond dimension: 4
# Energy = -32.77026020916624, energy change = -7.298936893107566e-6
# Step 255
# Maximal bond dimension: 4
# Energy = -32.770267221141914, energy change = -7.011975675652593e-6
# Step 256
# Maximal bond dimension: 4
# Energy = -32.77027395898432, energy change = -6.737842404902494e-6
# Step 257
# Maximal bond dimension: 4
# Energy = -32.77028043483075, energy change = -6.475846433318111e-6
# Step 258
# Maximal bond dimension: 4
# Energy = -32.77028666017382, energy change = -6.225343064159006e-6
# Step 259
# Maximal bond dimension: 4
# Energy = -32.77029264590374, energy change = -5.985729920610083e-6
# Step 260
# Maximal bond dimension: 4
# Energy = -32.77029840234724, energy change = -5.756443499649322e-6
# Step 261
# Maximal bond dimension: 4
# Energy = -32.770303939303496, energy change = -5.536956258822556e-6
# Step 262
# Maximal bond dimension: 4
# Energy = -32.770326707003925, energy change = -2.2767700428971693e-5
# Step 263
# Maximal bond dimension: 4
# Energy = -32.77036416082254, energy change = -3.745381861364194e-5
# Step 264
# Maximal bond dimension: 4
# Energy = -32.77039659544328, energy change = -3.2434620742094467e-5
# Step 265
# Maximal bond dimension: 4
# Energy = -32.77042477792699, energy change = -2.8182483710281758e-5
# Step 266
# Maximal bond dimension: 4
# Energy = -32.77044935304695, energy change = -2.4575119958569758e-5
# Step 267
# Maximal bond dimension: 4
# Energy = -32.77047086312667, energy change = -2.1510079719178066e-5
# Step 268
# Maximal bond dimension: 4
# Energy = -32.77048976462376, energy change = -1.8901497092826958e-5
# Step 269
# Maximal bond dimension: 4
# Energy = -32.770506441999096, energy change = -1.6677375334950284e-5
# Step 270
# Maximal bond dimension: 4
# Energy = -32.7705212193195, energy change = -1.477732040200408e-5
# Step 271
# Maximal bond dimension: 4
# Energy = -32.77053436996801, energy change = -1.3150648513260421e-5
# Step 272
# Maximal bond dimension: 4
# Energy = -32.77054612477332, energy change = -1.1754805306907201e-5
# Step 273
# Maximal bond dimension: 4
# Energy = -32.770556678818146, energy change = -1.055404482741551e-5
# Step 274
# Maximal bond dimension: 4
# Energy = -32.770566197143545, energy change = -9.518325398971683e-6
# Step 275
# Maximal bond dimension: 4
# Energy = -32.77057481952964, energy change = -8.6223860975565e-6
# Step 276
# Maximal bond dimension: 4
# Energy = -32.77058266450417, energy change = -7.84497452599453e-6
# Step 277
# Maximal bond dimension: 4
# Energy = -32.770589832704665, energy change = -7.168200497176258e-6
# Step 278
# Maximal bond dimension: 4
# Energy = -32.77059640969963, energy change = -6.576994962870231e-6
# Step 279
# Maximal bond dimension: 4
# Energy = -32.77060246835669, energy change = -6.058657064045292e-6
# Step 280
# Maximal bond dimension: 4
# Energy = -32.7706080708314, energy change = -5.602474708155114e-6
# Step 281
# Maximal bond dimension: 4
# Energy = -32.77061327023793, energy change = -5.1994065302096715e-6
# Step 282
# Maximal bond dimension: 4
# Energy = -32.77061811205336, energy change = -4.841815432143903e-6
# Step 283
# Maximal bond dimension: 4
# Energy = -32.77062263529843, energy change = -4.523245067389325e-6
# Step 284
# Maximal bond dimension: 4
# Energy = -32.77062687353091, energy change = -4.238232477860038e-6
# Step 285
# Maximal bond dimension: 4
# Energy = -32.77063085568158, energy change = -3.982150673209617e-6
# Step 286
# Maximal bond dimension: 4
# Energy = -32.77063460675823, energy change = -3.751076647517948e-6
# Step 287
# Maximal bond dimension: 4
# Energy = -32.77063814843879, energy change = -3.5416805630461567e-6
# Step 288
# Maximal bond dimension: 4
# Energy = -32.770641499571354, energy change = -3.3511325625568134e-6
# Step 289
# Maximal bond dimension: 4
# Energy = -32.77064467659587, energy change = -3.177024517242444e-6
# Step 290
# Maximal bond dimension: 4
# Energy = -32.770647693900024, energy change = -3.0173041523084976e-6
# Step 291
# Maximal bond dimension: 4
# Energy = -32.77065056411996, energy change = -2.870219937278762e-6
# Step 292
# Maximal bond dimension: 4
# Energy = -32.770653298394244, energy change = -2.734274282545357e-6
# Step 293
# Maximal bond dimension: 4
# Energy = -32.77065590657878, energy change = -2.608184537677971e-6
# Step 294
# Maximal bond dimension: 4
# Energy = -32.77065839742865, energy change = -2.4908498659215184e-6
# Step 295
# Maximal bond dimension: 4
# Energy = -32.77066077875225, energy change = -2.3813236040837182e-6
# Step 296
# Maximal bond dimension: 4
# Energy = -32.77066305754187, energy change = -2.2787896156728493e-6
# Step 297
# Maximal bond dimension: 4
# Energy = -32.77066524008472, energy change = -2.182542850448499e-6
# Step 298
# Maximal bond dimension: 4
# Energy = -32.77066733205702, energy change = -2.0919723056067596e-6
# Step 299
# Maximal bond dimension: 4
# Energy = -32.770669338604286, energy change = -2.0065472625674374e-6
# Step 300
# Maximal bond dimension: 4
# Energy = -32.77067126440961, energy change = -1.9258053214343818e-6
# Step 301
# Maximal bond dimension: 4
# Energy = -32.77067311375186, energy change = -1.8493422544452187e-6
# Step 302
# Maximal bond dimension: 4
# Energy = -32.77067489055546, energy change = -1.776803600250787e-6
# Step 303
# Maximal bond dimension: 4
# Energy = -32.77067659843297, energy change = -1.7078775087497888e-6
# Step 304
# Maximal bond dimension: 4
# Energy = -32.77067824072157, energy change = -1.642288601999553e-6
# Step 305
# Maximal bond dimension: 4
# Energy = -32.77067982051442, energy change = -1.5797928440974829e-6
# Step 306
# Maximal bond dimension: 4
# Energy = -32.77068134068752, energy change = -1.5201731002889574e-6
# Step 307
# Maximal bond dimension: 4
# Energy = -32.77068280392306, energy change = -1.4632355416210885e-6
# Step 308
# Maximal bond dimension: 4
# Energy = -32.770684212729385, energy change = -1.4088063267081452e-6
# Step 309
# Maximal bond dimension: 4
# Energy = -32.77068556945852, energy change = -1.3567291361482603e-6
# Step 310
# Maximal bond dimension: 4
# Energy = -32.77068687632119, energy change = -1.3068626714130005e-6
# Step 311
# Maximal bond dimension: 4
# Energy = -32.77068813539998, energy change = -1.2590787861199715e-6
# Step 312
# Maximal bond dimension: 4
# Energy = -32.77068934866088, energy change = -1.213260901522517e-6
# Step 313
# Maximal bond dimension: 4
# Energy = -32.77069051796325, energy change = -1.169302372261427e-6
# Step 314
# Maximal bond dimension: 4
# Energy = -32.77069164506878, energy change = -1.1271055271322439e-6
# Step 315
# Maximal bond dimension: 4
# Energy = -32.77069273164924, energy change = -1.0865804611626118e-6
# Step 316
# Maximal bond dimension: 4
# Energy = -32.770693779293346, energy change = -1.047644104801293e-6
# Step 317
# Maximal bond dimension: 4
# Energy = -32.770694789512966, energy change = -1.0102196199568425e-6
# Step 318
# Maximal bond dimension: 4
# Energy = -32.770695763748535, energy change = -9.74235568662607e-7
# Step 319
# Maximal bond dimension: 4
# Energy = -32.770696703373886, energy change = -9.396253517479636e-7
# Step 320
# Maximal bond dimension: 4
# Energy = -32.770697609700704, energy change = -9.063268180398154e-7
# Step 321
# Maximal bond dimension: 4
# Energy = -32.770698483982486, energy change = -8.742817811935311e-7
# Step 322
# Maximal bond dimension: 4
# Energy = -32.77069932741806, energy change = -8.434355720510212e-7
# Step 323
# Maximal bond dimension: 4
# Energy = -32.77070014115479, energy change = -8.137367331073619e-7
# Step 324
# Maximal bond dimension: 4
# Energy = -32.770700926291624, energy change = -7.85136833769684e-7
# Step 325
# Maximal bond dimension: 4
# Energy = -32.770701683881725, energy change = -7.575901008749497e-7
# Step 326
# Maximal bond dimension: 4
# Energy = -32.77070241493493, energy change = -7.310532055271324e-7
# Step 327
# Maximal bond dimension: 4
# Energy = -32.77070312042008, energy change = -7.054851494103787e-7
# Step 328
# Maximal bond dimension: 4
# Energy = -32.77070380126701, energy change = -6.808469308339227e-7
# Step 329
# Maximal bond dimension: 4
# Energy = -32.77070445836864, energy change = -6.571016299972143e-7
# Step 330
# Maximal bond dimension: 4
# Energy = -32.77070509258266, energy change = -6.342140181914147e-7
# Step 331
# Maximal bond dimension: 4
# Energy = -32.77070570473324, energy change = -6.121505791156778e-7
# Step 332
# Maximal bond dimension: 4
# Energy = -32.77070629561261, energy change = -5.908793738740314e-7
# Step 333
# Maximal bond dimension: 4
# Energy = -32.77070686598249, energy change = -5.703698775505472e-7
# Step 334
# Maximal bond dimension: 4
# Energy = -32.77070741657548, energy change = -5.505929934201959e-7
# Step 335
# Maximal bond dimension: 4
# Energy = -32.7707079480964, energy change = -5.31520917945727e-7
# Step 336
# Maximal bond dimension: 4
# Energy = -32.77070846122338, energy change = -5.131269773528402e-7
# Step 337
# Maximal bond dimension: 4
# Energy = -32.77070895660912, energy change = -4.953857413170226e-7
# Step 338
# Maximal bond dimension: 4
# Energy = -32.77070943488192, energy change = -4.782728026953009e-7
# Step 339
# Maximal bond dimension: 4
# Energy = -32.770709896646665, energy change = -4.6176474199910444e-7
# Step 340
# Maximal bond dimension: 4
# Energy = -32.77071034248592, energy change = -4.4583925529195767e-7
# Step 341
# Maximal bond dimension: 4
# Energy = -32.77071077296066, energy change = -4.304747420746935e-7
# Step 342
# Maximal bond dimension: 4
# Energy = -32.77071118861135, energy change = -4.156506889785305e-7
# Step 343
# Maximal bond dimension: 4
# Energy = -32.770711589958545, energy change = -4.013471937014401e-7
# Step 344
# Maximal bond dimension: 4
# Energy = -32.77071197750391, energy change = -3.875453629120784e-7
# Step 345
# Maximal bond dimension: 4
# Energy = -32.77071235173079, energy change = -3.742268859241449e-7
# Step 346
# Maximal bond dimension: 4
# Energy = -32.77071271310504, energy change = -3.61374247859203e-7
# Step 347
# Maximal bond dimension: 4
# Energy = -32.770713062075636, energy change = -3.489705946435606e-7
# Step 348
# Maximal bond dimension: 4
# Energy = -32.77071339907537, energy change = -3.369997330082697e-7
# Step 349
# Maximal bond dimension: 4
# Energy = -32.77071372452147, energy change = -3.254461020674171e-7
# Step 350
# Maximal bond dimension: 4
# Energy = -32.77071403881616, energy change = -3.142946880529962e-7
# Step 351
# Maximal bond dimension: 4
# Energy = -32.770714342347276, energy change = -3.035311166854626e-7
# Step 352
# Maximal bond dimension: 4
# Energy = -32.770714635488794, energy change = -2.931415181706143e-7
# Step 353
# Maximal bond dimension: 4
# Energy = -32.770714918601335, energy change = -2.831125414104463e-7
# Step 354
# Maximal bond dimension: 4
# Energy = -32.77071519203272, energy change = -2.734313824248602e-7
# Step 355
# Maximal bond dimension: 4
# Energy = -32.770715456118346, energy change = -2.640856280322623e-7
# Step 356
# Maximal bond dimension: 4
# Energy = -32.770715711181786, energy change = -2.5506344059067487e-7
# Step 357
# Maximal bond dimension: 4
# Energy = -32.77071595753508, energy change = -2.4635329509692383e-7
# Step 358
# Maximal bond dimension: 4
# Energy = -32.77071619547932, energy change = -2.3794423498202377e-7
# Step 359
# Maximal bond dimension: 4
# Energy = -32.77071642530491, energy change = -2.2982559499951094e-7
# Step 360
# Maximal bond dimension: 4
# Energy = -32.77071664729202, energy change = -2.219871078068536e-7
# Step 361
# Maximal bond dimension: 4
# Energy = -32.77071686171098, energy change = -2.144189608088709e-7
# Step 362
# Maximal bond dimension: 4
# Energy = -32.770717068822634, energy change = -2.0711165404918574e-7
# Step 363
# Maximal bond dimension: 4
# Energy = -32.770717268878606, energy change = -2.000559717885153e-7
# Step 364
# Maximal bond dimension: 4
# Energy = -32.77071746212177, energy change = -1.932431672457824e-7
# Step 365
# Maximal bond dimension: 4
# Energy = -32.77071764878647, energy change = -1.8666469969730315e-7
# Step 366
# Maximal bond dimension: 4
# Energy = -32.77071782909883, energy change = -1.803123552690522e-7
# Step 367
# Maximal bond dimension: 4
# Energy = -32.7707180032771, energy change = -1.7417827535837205e-7
# Step 368
# Maximal bond dimension: 4
# Energy = -32.770718171531904, energy change = -1.6825480031457118e-7
# Step 369
# Maximal bond dimension: 4
# Energy = -32.770718334066544, energy change = -1.6253463996918072e-7
# Step 370
# Maximal bond dimension: 4
# Energy = -32.770718491077204, energy change = -1.570106604731336e-7
# Step 371
# Maximal bond dimension: 4
# Energy = -32.77071864275326, energy change = -1.516760548270213e-7
# Step 372
# Maximal bond dimension: 4
# Energy = -32.770718789277524, energy change = -1.4652426472139268e-7
# Step 373
# Maximal bond dimension: 4
# Energy = -32.77071893082641, energy change = -1.415488881661986e-7
# Step 374
# Maximal bond dimension: 4
# Energy = -32.7707190675703, energy change = -1.3674388554818506e-7
# Step 375
# Maximal bond dimension: 4
# Energy = -32.770719199673565, energy change = -1.3210326699208963e-7
# Step 376
# Maximal bond dimension: 4
# Energy = -32.77071932729493, energy change = -1.2762136236688093e-7
# Step 377
# Maximal bond dimension: 4
# Energy = -32.77071945058763, energy change = -1.232927004934936e-7
# Step 378
# Maximal bond dimension: 4
# Energy = -32.770719569699594, energy change = -1.1911196651226419e-7
# Step 379
# Maximal bond dimension: 4
# Energy = -32.77071968477367, energy change = -1.1507407293720462e-7
# Step 380
# Maximal bond dimension: 4
# Energy = -32.77071979594767, energy change = -1.1117400333660044e-7
# Step 381
# Maximal bond dimension: 4
# Energy = -32.7707199033548, energy change = -1.0740713207724184e-7
# Step 382
# Maximal bond dimension: 4
# Energy = -32.770720007123515, energy change = -1.0376871273365396e-7
# Step 383
# Maximal bond dimension: 4
# Energy = -32.77072010737798, energy change = -1.0025446783856751e-7
# Step 384
# Maximal bond dimension: 4
# STOP due to energy convergence. Final energy:-32.770720204237975

# %%
function Ising_energy_exact(N::Int64,g::Float64)
    ## Open boundary condition, boundary field cut half
    H_majorana = zeros(2*N,2*N)
    for i in 1:N
        if(i==1 || i==N)
            H_majorana[2*i-1,2*i] = -g/2
        else
            H_majorana[2*i-1,2*i] = -g
        end
        if (i<N)
            H_majorana[2*i,2*i+1] = -1
        end
    end
    H_majorana = H_majorana - H_majorana'
    T,Z = schur(H_majorana)
    Es = [T[2*i-1,2*i] for i in 1:N]
    E0 = -sum(abs.(Es))
    return E0
end
# Out:
# Ising_energy_exact (generic function with 1 method)

# %%
Ising_energy_exact(L,g)
# Out:
# -32.78014564399475
